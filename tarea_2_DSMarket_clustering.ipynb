# %% [markdown]
# # Clustering

# %% [markdown]
# ## 1. Importing libraries and files

# %%
import numpy as np 
import pandas as pd

# %%
df_weekly = pd.read_csv('./Data_for_Power_BI/weekly_data_for_power_bi.csv')
